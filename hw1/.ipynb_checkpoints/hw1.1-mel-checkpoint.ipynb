# %%
import numpy as np  ## numpy is general purpose array processing package
import math
import matplotlib.pyplot as plt

# %%
# Create random input and output data
x = np.linspace(-math.pi, math.pi, 2000)
y = np.sin(x)
print(x)
print(y)
# Out:
# [-3.14159265 -3.13844949 -3.13530633 ...  3.13530633  3.13844949
#   3.14159265]
# [-1.22464680e-16 -3.14315906e-03 -6.28628707e-03 ...  6.28628707e-03
#   3.14315906e-03  1.22464680e-16]

# %%
# Randomly initialize weights: these will be trained
a = np.random.randn()
b = np.random.randn()
c = np.random.randn()
d = np.random.randn()
print(a, b, c, d)
# Out:
# 0.4818897230422468 -0.129549957597488 1.4556578767786303 0.9103372410780384

# %%
learning_rate = 1e-3
learning_epoch = 3000

for t in range(learning_epoch):
    # Forward pass: compute predicted y
    # y = a + b x + c x^2 + d x^3
    y_pred = a + b * x + c * x ** 2 + d * x ** 3

    # Compute and print loss
    loss = np.square(y_pred - y).sum()/len(y) # Mean Square Error
    if t % 100 == 0:
        print(t,'-th iteration loss:', loss)

    # Backprop to compute gradients of a, b, c, d with respect to loss
    grad_y_pred = 2.0 * (y_pred - y)/len(y)
    grad_a = grad_y_pred.sum()
    grad_b = (grad_y_pred * x).sum()
    grad_c = (grad_y_pred * x ** 2).sum()
    grad_d = (grad_y_pred * x ** 3).sum()

    # Update weights   vanilla gradiant decent
    a -= learning_rate * grad_a
    b -= learning_rate * grad_b
    c -= learning_rate * grad_c
    d -= learning_rate * grad_d

print(f'Result: y = {a} + {b} x + {c} x^2 + {d} x^3')  ## f' allows to embed any variable inside the string.

plt.plot(x, y,      label = "Answer")
plt.plot(x, y_pred, label = "Predicted")
# show a legend on the plot
plt.legend()
# Out:
# 0 -th iteration loss: 149.54213090299558
# 100 -th iteration loss: 0.5607034452010498
# 200 -th iteration loss: 0.44704810833831476
# 300 -th iteration loss: 0.364829808229151
# 400 -th iteration loss: 0.2978974608020786
# 500 -th iteration loss: 0.24340490465312262
# 600 -th iteration loss: 0.19903852150878906
# 700 -th iteration loss: 0.1629152487191858
# 800 -th iteration loss: 0.13350241305439636
# 900 -th iteration loss: 0.10955249796976495
# 1000 -th iteration loss: 0.09005006084933473
# 1100 -th iteration loss: 0.07416853635316187
# 1200 -th iteration loss: 0.061235083954679116
# 1300 -th iteration loss: 0.05070198104390635
# 1400 -th iteration loss: 0.04212334226227402
# 1500 -th iteration loss: 0.03513617295956118
# 1600 -th iteration loss: 0.029444949531428663
# 1700 -th iteration loss: 0.02480906980502608
# 1800 -th iteration loss: 0.021032639014979797
# 1900 -th iteration loss: 0.01795615647940286
# 2000 -th iteration loss: 0.015449749097354849
# 2100 -th iteration loss: 0.013407663704517053
# 2200 -th iteration loss: 0.011743783956808139
# 2300 -th iteration loss: 0.010387981051636021
# 2400 -th iteration loss: 0.009283143105989586
# 2500 -th iteration loss: 0.00838275690490519
# 2600 -th iteration loss: 0.007648939245806382
# 2700 -th iteration loss: 0.007050834236779805
# 2800 -th iteration loss: 0.006563308476057136
# 2900 -th iteration loss: 0.006165888709731926
# Result: y = 0.01677180778667694 + 0.8069146860877457 x + -0.0028934159272879898 x^2 + -0.08624305209932728 x^3
